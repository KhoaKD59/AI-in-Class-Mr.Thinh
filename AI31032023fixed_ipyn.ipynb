# %% [markdown]
# <a href="https://colab.research.google.com/github/KhoaKD59/AI-in-Class-Mr.Thinh/blob/main/AI31032023fixed_ipyn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.datasets import mnist #khai báo tập dữ liệu keras trong mnits
(train_images,train_labels), (test_images,test_labels) = mnist.load_data()

# %%
print(train_images.shape)
# Out:
# (60000, 28, 28)

# %%
print(test_images.shape)
# Out:
# (10000, 28, 28)

# %%
X = test_images #lưu giữ số cũ
Y = test_labels

# %%
import matplotlib.pyplot as plt
high = train_images[41546]
plt.imshow(high, cmap= plt.cm.binary)
plt.show
print('số này là: ', train_labels[41546])
# Out:
# số này là:  6

# %%
for i in range(25):
 plt.subplot(5,5, i+1)
 plt.tight_layout()
 plt.imshow(train_images[i], cmap ='gray', interpolation = 'none')
 plt.title('So: {}'.format(train_labels[i]))
 plt.xticks([])
 plt.yticks([])

# %%
from keras import models
from keras.layers import Dense

from keras.layers.attention.multi_head_attention import activation
model = models.Sequential()
model.add(Dense(512, activation = 'relu', input_shape =(28*28,), name='layer_1'))
model.add(Dense(10, activation ='softmax', name='layer_out'))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  layer_1 (Dense)             (None, 512)               401920
#
#  layer_out (Dense)           (None, 10)                5130
#
# ...
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_images = train_images.reshape((60000, 28*28))
train_images = train_images.astype('float32') / 255
test_images = test_images.reshape((10000, 28*28))  # sửa lại thành biến test_images
test_images = test_images.astype('float32') / 255

# %%
from keras.utils import to_categorical
train_labels = to_categorical(train_labels,10)
test_labels = to_categorical(test_labels,10)
print(train_labels.shape)
print(test_labels.shape)
# Out:
# (60000, 10)
# (10000, 10)

# %%
## data -> model -> compile -> train -> Evaluation

# %%
#compile
model.compile(optimizer = 'rmsprop', loss = 'categorical_crossentropy', metrics = ['accuracy'])  #chon bo toi uu, danh gia do mat mat, do chinh xac  
#train
model.fit(train_images, train_labels, epochs = 10, batch_size = 128 ) # epochs: so lan hoc, bath_size: so du lieu moi lan hoc, boc ngau nhien 128
#evaluate, do do chinh xac
test_loss , test_acc = model.evaluate(test_images, test_labels)
print('Do mat mat :', test_loss)
print('Do chinh xac :', test_acc)
# Out:
# Epoch 1/10
# 469/469 [==============================] - 10s 20ms/step - loss: 0.2653 - accuracy: 0.9234
# Epoch 2/10
# 469/469 [==============================] - 10s 21ms/step - loss: 0.1085 - accuracy: 0.9674
# Epoch 3/10
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0700 - accuracy: 0.9790
# Epoch 4/10
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0502 - accuracy: 0.9850
# Epoch 5/10
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0385 - accuracy: 0.9890
# Epoch 6/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0290 - accuracy: 0.9912
# Epoch 7/10
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0221 - accuracy: 0.9939
# Epoch 8/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0158 - accuracy: 0.9957
# Epoch 9/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0123 - accuracy: 0.9970
# Epoch 10/10
# ...

# %%
# X[10]
import numpy as np
import matplotlib.pyplot as plt
img = X[10]
plt.imshow(img,cmap='gray')
plt.show
print(Y[10])
# Out:
# 0

# %%
import numpy as np
import matplotlib.pyplot as plt
X_pred = X[1000]
X_pred = X_pred.reshape((1,28*28))  #reshape: chuyen anh 2 chieu sang anh 1 chieu 
X_pred = X_pred.astype('float32')/255
predicted_label = np.argmax(model.predict(X_pred), axis=-1)
print("Predicted label:", predicted_label)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# Predicted label: [8]

# %%
form keras.datasets.cifar10.load_data
